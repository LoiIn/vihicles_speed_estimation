# %%
# !git clone https://github.com/LoiIn/vihicles_speed_estimation.git

# %%
# %cd vihicles_speed_estimation/server

# %%
# !pip install tensorflow-gpu==2.3.0

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.weights -P data/

# %%
# !python save_model.py

# %%
# !mkdir ./data/videos
# !mkdir ./outputs
# !mkdir ./outputs/mp4
# !mkdir ./outputs/csv
# !mkdir ./outputs/csv1
# !mkdir ./outputs/imgs

# %%
# !gdown 1jH-npQKOLbSvZ4v7fWnW2-trDctfT3Xq --output ./data/videos.zip
# !apt install unzip
# !unzip ./data/videos.zip -d ./data/videos

# %%
# !python speed.py --input vu1.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vu2.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vu3.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vu4.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vf1.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vf2.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vf3.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vf4.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vs1.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vs2.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vs3.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# !python speed.py --input vs4.mp4 --points 15 --A_point 0 --rwf 5 --rws 12 --limit 20
# Out:
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!
# you are using GPU ...
# Video has ended or failed, try a different video format!

# %%
# !zip -r ./outputs/csv.zip ./outputs/csv
# !zip -r ./outputs/csv1.zip ./outputs/csv1
# !zip -r ./outputs/imgs.zip ./outputs/imgs
# !zip -r ./outputs/videos.zip ./outputs/mp4
# Out:
#   adding: outputs/imgs/ (stored 0%)
#   adding: outputs/imgs/Aug-07-2022_vs1/ (stored 0%)
#   adding: outputs/imgs/Aug-07-2022_vs1/6.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vs1/9.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vu4/ (stored 0%)
#   adding: outputs/imgs/Aug-07-2022_vu4/5.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vu4/8.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vf4/ (stored 0%)
#   adding: outputs/imgs/Aug-07-2022_vf4/10.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vs4/ (stored 0%)
#   adding: outputs/imgs/Aug-07-2022_vs4/5.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vu1/ (stored 0%)
#   adding: outputs/imgs/Aug-07-2022_vu1/9.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vu1/7.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vf3/ (stored 0%)
#   adding: outputs/imgs/Aug-07-2022_vf3/4.jpg (deflated 0%)
#   adding: outputs/imgs/Aug-07-2022_vs3/ (stored 0%)
# ...
